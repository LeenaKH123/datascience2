# %% [markdown]
# Python code for data loading and analysis -
# Creating the DataDictionary

# %%
import pandas as pd
# Load the dataset
df = pd.read_csv('Telco-Customer-Churn.csv')
# Get data structure overview
data_dictionary = pd.DataFrame({
    "Attribute Name": df.columns,
    "Data Type": df.dtypes.values,
    "Missing Values": df.isnull().sum().values,
    "Unique Values": df.nunique().values
})
# Display the data dictionary
#print("Data Dictionary Overview:")
#print(data_dictionary)
from IPython.display import display
# Display Data Dictionary in Jupyter Notebook
display(data_dictionary)
# Out:
#       Attribute Name Data Type  Missing Values  Unique Values
# 0         customerID    object               0           7043
# 1             gender    object               0              2
# 2      SeniorCitizen     int64               0              2
# 3            Partner    object               0              2
# 4         Dependents    object               0              2
# 5             tenure     int64               0             73
# 6       PhoneService    object               0              2
# 7      MultipleLines    object               0              3
# 8    InternetService    object               0              3
# 9     OnlineSecurity    object               0              3
# 10      OnlineBackup    object               0              3
# 11  DeviceProtection    object               0              3
# 12       TechSupport    object               0              3
# 13       StreamingTV    object               0              3
# 14   StreamingMovies    object               0              3
# 15          Contract    object               0              3
# 16  PaperlessBilling    object               0              2
# 17     PaymentMethod    object               0              4
# 18    MonthlyCharges   float64               0           1585
# 19      TotalCharges    object               0           6531
# 20             Churn    object               0              2

# %% [markdown]
# Data Ingestion - with Pandas

# %%
#import pandas as pd

# Load the dataset into a Pandas DataFrame
df = pd.read_csv('Telco-Customer-Churn.csv')
# Display first few rows
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %% [markdown]
# Data Ingestion - SQL DB

# %%
#import pandas as pd
from sqlalchemy import create_engine
import psycopg2

# Load the dataset into a Pandas DataFrame
df = pd.read_csv('Telco-Customer-Churn.csv')

# Define PostgreSQL connection using default credentials
db_engine = create_engine('postgresql://postgres:postgres@localhost:5432/postgres')

# Load DataFrame into PostgreSQL (Table: telco_customer_churn)
df.to_sql('telco_customer_churn', db_engine, if_exists='replace', index=False)

print("✅ Data successfully loaded into PostgreSQL database!")

# Connect to PostgreSQL to execute a query
try:
    conn = psycopg2.connect("dbname='postgres' user='postgres' password='postgres' host='localhost' port='5432'")
    cursor = conn.cursor()

    # Execute SQL query to fetch first 5 rows
    query = "SELECT * FROM telco_customer_churn LIMIT 5;"
    cursor.execute(query)

    # Fetch and display results
    rows = cursor.fetchall()
    print("\n📊 First 5 Rows from telco_customer_churn Table:")
    for row in rows:
        print(row)

    # Close connection
    cursor.close()
    conn.close()
except Exception as e:
    print("❌ Error connecting to PostgreSQL:", e)
# Out:
# ✅ Data successfully loaded into PostgreSQL database!
#
# 📊 First 5 Rows from telco_customer_churn Table:
# ('7590-VHVEG', 'Female', 0, 'Yes', 'No', 1, 'No', 'No phone service', 'DSL', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Month-to-month', 'Yes', 'Electronic check', 29.85, '29.85', 'No')
# ('5575-GNVDE', 'Male', 0, 'No', 'No', 34, 'Yes', 'No', 'DSL', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'One year', 'No', 'Mailed check', 56.95, '1889.5', 'No')
# ('3668-QPYBK', 'Male', 0, 'No', 'No', 2, 'Yes', 'No', 'DSL', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Month-to-month', 'Yes', 'Mailed check', 53.85, '108.15', 'Yes')
# ('7795-CFOCW', 'Male', 0, 'No', 'No', 45, 'No', 'No phone service', 'DSL', 'Yes', 'No', 'Yes', 'Yes', 'No', 'No', 'One year', 'No', 'Bank transfer (automatic)', 42.3, '1840.75', 'No')
# ('9237-HQITU', 'Female', 0, 'No', 'No', 2, 'Yes', 'No', 'Fiber optic', 'No', 'No', 'No', 'No', 'No', 'No', 'Month-to-month', 'Yes', 'Electronic check', 70.7, '151.65', 'Yes')

# %% [markdown]
# Checking for missing values using Pandas

# %%
missing_values = df.isnull().sum()
print("Missing Values:\n", missing_values)
# Out:
# Missing Values:
#  customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# finding missing values using SQL

# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2

# Load the dataset into a Pandas DataFrame
df = pd.read_csv("Telco-Customer-Churn.csv")

# Define PostgreSQL connection using default credentials
db_engine = create_engine('postgresql://postgres:postgres@localhost:5432/postgres')

# Load DataFrame into PostgreSQL (Table: telco_customer_churn)
df.to_sql('telco_customer_churn', db_engine, if_exists='replace', index=False)

print("✅ Data successfully loaded into PostgreSQL database!")
# Out:
# ✅ Data successfully loaded into PostgreSQL database!

# %%
# Define PostgreSQL connection
conn = psycopg2.connect("dbname='postgres' user='postgres' password='postgres' host='localhost' port='5432'")
cursor = conn.cursor()

# Function to run SQL queries and return results
def run_sql_query(query):
    cursor.execute(query)
    rows = cursor.fetchall()
    for row in rows:
        print(row)

# Ensure connection works
print("✅ Connected to PostgreSQL successfully!")
# Out:
# ✅ Connected to PostgreSQL successfully!

# %%
missing_values = df.isnull().sum()
print("Missing Values:\n", missing_values)
# Out:
# Missing Values:
#  customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
run_sql_query("""
SELECT column_name, COUNT(*) - COUNT(column_name) AS missing_values
FROM information_schema.columns
LEFT JOIN (
    SELECT * FROM telco_customer_churn
) t ON column_name = column_name
GROUP BY column_name;
""")
# Out:
# ('provolatile', 0)
# ('srsublsn', 0)
# ('stxkind', 0)
# ('aggmtransspace', 0)
# ('indisprimary', 0)
# ('funcname', 0)
# ('comments', 0)
# ('stacoll2', 0)
# ('mode', 0)
# ('virtualxid', 0)
# ('pubowner', 0)
# ('privtype', 0)
# ('adnum', 0)
# ('StreamingTV', 0)
# ('applied', 0)
# ('identity_maximum', 0)
# ('MultipleLines', 0)
# ('ref_dtd_identifier', 0)
# ('cfgowner', 0)
# ('umoptions', 0)
# ('last_autovacuum', 0)
# ('blks_exists', 0)
# ('datoid', 0)
# ('relfrozenxid', 0)
# ('srrelid', 0)
# ('amopsortfamily', 0)
# ('adbin', 0)
# ('maptokentype', 0)
# ('ext_stats_computed', 0)
# ('client_dn', 0)
# ('blk_write_time', 0)
# ('partitions_done', 0)
# ('relacl', 0)
# ('provariadic', 0)
# ('subslotname', 0)
# ('identity_start', 0)
# ('ordering_form', 0)
# ('event_object_catalog', 0)
# ('is_grantable', 0)
# ('indimmediate', 0)
# ('rolpassword', 0)
# ('seqstart', 0)
# ('action_timing', 0)
# ('column_default', 0)
# ('numeric_precision', 0)
# ('xact_start', 0)
# ('wal_distance', 0)
# ('indrelid', 0)
# ('lanvalidator', 0)
# ('relpartbound', 0)
# ('extrelocatable', 0)
# ('aggfnoid', 0)
# ('xact_commit', 0)
# ('schema_owner', 0)
# ('stakind5', 0)
# ('relhassubclass', 0)
# ('pronargdefaults', 0)
# ('wal_status', 0)
# ('backend_xid', 0)
# ('reloftype', 0)
# ('state', 0)
# ('sessions', 0)
# ('numbackends', 0)
# ('typnotnull', 0)
# ('blocks_total', 0)
# ('received_tli', 0)
# ('coninhcount', 0)
# ('attidentity', 0)
# ('current_child_table_relid', 0)
# ('domain_catalog', 0)
# ('SeniorCitizen', 0)
# ('is_deferrable', 0)
# ('view_schema', 0)
# ('lockers_done', 0)
# ('inhdetachpending', 0)
# ('object_name', 0)
# ('character_set_schema', 0)
# ('statistics_owner', 0)
# ('rolname', 0)
# ('attisdropped', 0)
# ('userepl', 0)
# ('tablespace', 0)
# ('result_cast_char_set_schema', 0)
# ('column_name', 0)
# ('buffers_backend_fsync', 0)
# ('prsend', 0)
# ('increment', 0)
# ('wal_records', 0)
# ('write_lsn', 0)
# ('maxwritten_clean', 0)
# ('conname', 0)
# ('action_reference_old_table', 0)
# ('file_name', 0)
# ('mapdict', 0)
# ('aggmfinalfn', 0)
# ('relhasindex', 0)
# ('ev_qual', 0)
# ('oprnegate', 0)
# ('writes', 0)
# ('inhparent', 0)
# ('datname', 0)
# ('partclass', 0)
# ('collation_schema', 0)
# ('tgfoid', 0)
# ('implementation_info_id', 0)
# ('usesysid', 0)
# ('schemaname', 0)
# ('max_val', 0)
# ('stxdinherit', 0)
# ('tuples_done', 0)
# ('catalog_name', 0)
# ('authorization_identifier', 0)
# ('ordering_category', 0)
# ('indcollation', 0)
# ('typanalyze', 0)
# ('inherit_option', 0)
# ('confl_snapshot', 0)
# ('collprovider', 0)
# ('relam', 0)
# ('idx_blks_read', 0)
# ('subid', 0)
# ('event_manipulation', 0)
# ('idx_blks_hit', 0)
# ('wal_sync_time', 0)
# ('conflicting', 0)
# ('pubdelete', 0)
# ('specific_schema', 0)
# ('locktype', 0)
# ('tgnargs', 0)
# ('blks_zeroed', 0)
# ('oprrest', 0)
# ('conforencoding', 0)
# ('user_name', 0)
# ('local_lsn', 0)
# ('skip_init', 0)
# ('typacl', 0)
# ('MonthlyCharges', 0)
# ('allocated_size', 0)
# ('typdefault', 0)
# ('protrftypes', 0)
# ('spcoptions', 0)
# ('constraint_catalog', 0)
# ('label', 0)
# ('result_cast_numeric_precision_radix', 0)
# ('requires', 0)
# ('staop3', 0)
# ('sequence_schema', 0)
# ('sub_feature_id', 0)
# ('seq_tup_read', 0)
# ('attname', 0)
# ('tgenabled', 0)
# ('session_time', 0)
# ('roles', 0)
# ('castfunc', 0)
# ('attndims', 0)
# ('fdwowner', 0)
# ('n_tup_newpage_upd', 0)
# ('line_number', 0)
# ('result_cast_interval_type', 0)
# ('indexrelid', 0)
# ('conninfo', 0)
# ('conislocal', 0)
# ('archived_count', 0)
# ('indpred', 0)
# ('amoplefttype', 0)
# ('sessions_killed', 0)
# ('prosqlbody', 0)
# ('group_name', 0)
# ('qual', 0)
# ('useconfig', 0)
# ('refobjsubid', 0)
# ('daticulocale', 0)
# ('unique_constraint_schema', 0)
# ('tgdeferrable', 0)
# ('safe_wal_size', 0)
# ('wal_write', 0)
# ('boot_val', 0)
# ('attoptions', 0)
# ('roleid', 0)
# ('rowsecurity', 0)
# ('staop4', 0)
# ('datminmxid', 0)
# ('skip_rep', 0)
# ('confmatchtype', 0)
# ('last_vacuum', 0)
# ('idx_tup_fetch', 0)
# ('relallvisible', 0)
# ('conbin', 0)
# ('total_bytes', 0)
# ('indexdef', 0)
# ('toast_blks_read', 0)
# ('prefetch', 0)
# ('relispartition', 0)
# ('rolsuper', 0)
# ('tgisinternal', 0)
# ('subpasswordrequired', 0)
# ('last_altered', 0)
# ('amopstrategy', 0)
# ('stanumbers2', 0)
# ('valuntil', 0)
# ('subsynccommit', 0)
# ('trusted', 0)
# ('max_dead_tuples', 0)
# ('tmplnamespace', 0)
# ('fdwoptions', 0)
# ('proretset', 0)
# ('seqmin', 0)
# ('pg_username', 0)
# ('rolcreatedb', 0)
# ('calls', 0)
# ('customerID', 0)
# ('increment_by', 0)
# ('character_set_catalog', 0)
# ('is_dst', 0)
# ('child_tables_total', 0)
# ('character_octet_length', 0)
# ('lanpltrusted', 0)
# ('schema_name', 0)
# ('sequencename', 0)
# ('to_sql_specific_name', 0)
# ('polwithcheck', 0)
# ('update_rule', 0)
# ('typispreferred', 0)
# ('typalign', 0)
# ('implementation_info_name', 0)
# ('checkpoints_req', 0)
# ('checkpoint_sync_time', 0)
# ('slot_name', 0)
# ('tableowner', 0)
# ('relrowsecurity', 0)
# ('spcname', 0)
# ('mapcfg', 0)
# ('connoinherit', 0)
# ('viewname', 0)
# ('typbasetype', 0)
# ('cfgnamespace', 0)
# ('amtype', 0)
# ('max_dynamic_result_sets', 0)
# ('InternetService', 0)
# ('indkey', 0)
# ('pubinsert', 0)
# ('block_distance', 0)
# ('partcollation', 0)
# ('character_maximum_length', 0)
# ('form_of_use', 0)
# ('starelid', 0)
# ('defaclacl', 0)
# ('sequence_catalog', 0)
# ('umuser', 0)
# ('type', 0)
# ('collowner', 0)
# ('result_cast_collation_name', 0)
# ('typsubscript', 0)
# ('conflicts', 0)
# ('PaymentMethod', 0)
# ('spill_bytes', 0)
# ('prslextype', 0)
# ('total_txns', 0)
# ('grantee', 0)
# ('action_statement', 0)
# ('dtd_identifier', 0)
# ('waitstart', 0)
# ('tidx_blks_hit', 0)
# ('classid', 0)
# ('evttags', 0)
# ('vacuum_count', 0)
# ('is_udt_dependent', 0)
# ('attstattarget', 0)
# ('result_cast_type_udt_schema', 0)
# ('data', 0)
# ('pnnspid', 0)
# ('proconfig', 0)
# ('lanowner', 0)
# ('relchecks', 0)
# ('user_defined_type_name', 0)
# ('n_tup_hot_upd', 0)
# ('grolist', 0)
# ('conppeqop', 0)
# ('constraint_type', 0)
# ('new_savepoint_level', 0)
# ('usesuper', 0)
# ('hasrules', 0)
# ('suborigin', 0)
# ('confupdtype', 0)
# ('PhoneService', 0)
# ('opcfamily', 0)
# ('parameter_types', 0)
# ('ftserver', 0)
# ('stavalues2', 0)
# ('fdwname', 0)
# ('buffers_clean', 0)
# ('tuples_excluded', 0)
# ('check_option', 0)
# ('subname', 0)
# ('state_change', 0)
# ('kinds', 0)
# ('condeferred', 0)
# ('partitions_total', 0)
# ('inhrelid', 0)
# ('polcmd', 0)
# ('attcollation', 0)
# ('extnamespace', 0)
# ('udt_name', 0)
# ('foreign_server_name', 0)
# ('superuser', 0)
# ('used_bytes', 0)
# ('objid', 0)
# ('relnamespace', 0)
# ('typcategory', 0)
# ('stxdexpr', 0)
# ('ispopulated', 0)
# ('two_phase', 0)
# ('partnatts', 0)
# ('nspowner', 0)
# ('lanname', 0)
# ('relrewrite', 0)
# ('last_archived_wal', 0)
# ('typlen', 0)
# ('gid', 0)
# ('seq_scan', 0)
# ('result_cast_maximum_cardinality', 0)
# ('prpubid', 0)
# ('subdisableonerr', 0)
# ('apply_error_count', 0)
# ('free_chunks', 0)
# ('seqincrement', 0)
# ('confl_lock', 0)
# ('udt_schema', 0)
# ('active', 0)
# ('with_hierarchy', 0)
# ('conrelid', 0)
# ('feature_name', 0)
# ('oprresult', 0)
# ('rngsubopc', 0)
# ('fdwacl', 0)
# ('phase', 0)
# ('amopmethod', 0)
# ('tablename', 0)
# ('loid', 0)
# ('indisready', 0)
# ('type_udt_schema', 0)
# ('context', 0)
# ('sent_lsn', 0)
# ('idle_in_transaction_time', 0)
# ('amproclefttype', 0)
# ('staop1', 0)
# ('rngcanonical', 0)
# ('application_name', 0)
# ('ext_stats_total', 0)
# ('heap_blks_read', 0)
# ('bytes_total', 0)
# ('tgargs', 0)
# ('setdatabase', 0)
# ('relhasrules', 0)
# ('is_self_referencing', 0)
# ('atttypid', 0)
# ('dbid', 0)
# ('rolcreaterole', 0)
# ('idx_tup_read', 0)
# ('result_cast_char_set_name', 0)
# ('stxname', 0)
# ('privilege_type', 0)
# ('table_catalog', 0)
# ('skip_fpw', 0)
# ('sessions_fatal', 0)
# ('agginitval', 0)
# ('unique_constraint_name', 0)
# ('prsname', 0)
# ('wal_write_time', 0)
# ('ev_enabled', 0)
# ('proname', 0)
# ('status', 0)
# ('attacl', 0)
# ('attgenerated', 0)
# ('stacoll3', 0)
# ('fastpath', 0)
# ('relocatable', 0)
# ('max_value', 0)
# ('autovacuum_count', 0)
# ('polroles', 0)
# ('opckeytype', 0)
# ('action_reference_old_row', 0)
# ('user_defined_type_schema', 0)
# ('spcacl', 0)
# ('view_definition', 0)
# ('extowner', 0)
# ('avg_width', 0)
# ('set_option', 0)
# ('rolcanlogin', 0)
# ('proallargtypes', 0)
# ('rngtypid', 0)
# ('stacoll5', 0)
# ('attnum', 0)
# ('sync_priority', 0)
# ('fdwvalidator', 0)
# ('stxnamespace', 0)
# ('encrypted', 0)
# ('trigger_schema', 0)
# ('attcacheoff', 0)
# ('attlen', 0)
# ('external_language', 0)
# ('as_locator', 0)
# ('tup_updated', 0)
# ('seqcycle', 0)
# ('fsync_time', 0)
# ('evtevent', 0)
# ('prsstart', 0)
# ('subowner', 0)
# ('aggmfinalextra', 0)
# ('io_depth', 0)
# ('foreign_data_wrapper_language', 0)
# ('encoding', 0)
# ('aggfinalextra', 0)
# ('result_cast_type_udt_name', 0)
# ('extends', 0)
# ('lomacl', 0)
# ('pubtruncate', 0)
# ('typisdefined', 0)
# ('groname', 0)
# ('opfmethod', 0)
# ('replay_lag', 0)
# ('rolinherit', 0)
# ('prqual', 0)
# ('hastriggers', 0)
# ('heap_tuples_scanned', 0)
# ('transactionid', 0)
# ('stxddependencies', 0)
# ('domain_name', 0)
# ('utc_offset', 0)
# ('relforcerowsecurity', 0)
# ('write_lag', 0)
# ('adrelid', 0)
# ('last_idx_scan', 0)
# ('contypid', 0)
# ('datfrozenxid', 0)
# ('rolconnlimit', 0)
# ('bits', 0)
# ('aggtransspace', 0)
# ('routine_body', 0)
# ('match_option', 0)
# ('partexprs', 0)
# ('tablespaces_total', 0)
# ('latest_end_time', 0)
# ('n_tup_ins', 0)
# ('rowfilter', 0)
# ('usename', 0)
# ('analyze_count', 0)
# ('table_name', 0)
# ('staattnum', 0)
# ('attribute_udt_schema', 0)
# ('free_bytes', 0)
# ('datallowconn', 0)
# ('subpublications', 0)
# ('laninline', 0)
# ('client_port', 0)
# ('cfgparser', 0)
# ('result_cast_datetime_precision', 0)
# ('aggfinalmodify', 0)
# ('default_character_set_catalog', 0)
# ('stream_txns', 0)
# ('is_nullable', 0)
# ('start_value', 0)
# ('polpermissive', 0)
# ('client_serial', 0)
# ('admin_option', 0)
# ('probin', 0)
# ('oprname', 0)
# ('default_character_set_schema', 0)
# ('relnatts', 0)
# ('tuples_total', 0)
# ('last_msg_send_time', 0)
# ('proargnames', 0)
# ('colliculocale', 0)
# ('hit', 0)
# ('num_dead_tuples', 0)
# ('sys_name', 0)
# ('conffeqop', 0)
# ('prosecdef', 0)
# ('objtype', 0)
# ('oprcom', 0)
# ('ordinal_position', 0)
# ('opcnamespace', 0)
# ('blocks_done', 0)
# ('min_val', 0)
# ('result_cast_scope_schema', 0)
# ('identity_cycle', 0)
# ('result_cast_type_udt_catalog', 0)
# ('atthasdef', 0)
# ('cluster_index_relid', 0)
# ('heap_blks_hit', 0)
# ('initially_deferred', 0)
# ('contoencoding', 0)
# ('is_instead', 0)
# ('tgname', 0)
# ('pageno', 0)
# ('abbrev', 0)
# ('to_sql_specific_schema', 0)
# ('tgoldtable', 0)
# ('transform_type', 0)
# ('backup_streamed', 0)
# ('collversion', 0)
# ('wait_event', 0)
# ('dattablespace', 0)
# ('tup_inserted', 0)
# ('subconninfo', 0)
# ('conproc', 0)
# ('is_updatable', 0)
# ('setrole', 0)
# ('check_clause', 0)
# ('deptype', 0)
# ('srvoptions', 0)
# ('prstoken', 0)
# ('stacoll4', 0)
# ('object_catalog', 0)
# ('provider', 0)
# ('foreign_server_type', 0)
# ('trflang', 0)
# ('sourcefile', 0)
# ('n_distinct', 0)
# ('tgattr', 0)
# ('extcondition', 0)
# ('grantor', 0)
# ('sql_path', 0)
# ('n_dead_tup', 0)
# ('udt_catalog', 0)
# ('prorettype', 0)
# ('result_cast_char_max_length', 0)
# ('datlocprovider', 0)
# ('schema', 0)
# ('tginitdeferred', 0)
# ('tgconstraint', 0)
# ('is_user_defined_cast', 0)
# ('typnamespace', 0)
# ('prsheadline', 0)
# ('type_udt_name', 0)
# ('map_name', 0)
# ('staop2', 0)
# ('credentials_delegated', 0)
# ('stakind3', 0)
# ('option_value', 0)
# ('convalidated', 0)
# ('most_common_base_freqs', 0)
# ('confkey', 0)
# ('installed_version', 0)
# ('sender_port', 0)
# ('usecreatedb', 0)
# ('query_start', 0)
# ('typtype', 0)
# ('maximum_cardinality', 0)
# ('typmodin', 0)
# ('last_failed_wal', 0)
# ('stacoll1', 0)
# ('is_binary', 0)
# ('oid', 0)
# ('srvversion', 0)
# ('DeviceProtection', 0)
# ('enumvals', 0)
# ('reference_generation', 0)
# ('level', 0)
# ('relid', 0)
# ('wal_fpi', 0)
# ('toast_blks_hit', 0)
# ('amoprighttype', 0)
# ('module_name', 0)
# ('child_tables_done', 0)
# ('numeric_scale', 0)
# ('objsubid', 0)
# ('attmissingval', 0)
# ('seqmax', 0)
# ('srsubstate', 0)
# ('min_value', 0)
# ('data_type', 0)
# ('indislive', 0)
# ('is_identity', 0)
# ('page', 0)
# ('is_supported', 0)
# ('seqrelid', 0)
# ('Dependents', 0)
# ('buffers_backend', 0)
# ('StreamingMovies', 0)
# ('wal_buffers_full', 0)
# ('indclass', 0)
# ('parent', 0)
# ('relfilenode', 0)
# ('srvid', 0)
# ('result_cast_scope_name', 0)
# ('action_orientation', 0)
# ('indisclustered', 0)
# ('oprjoin', 0)
# ('defaclnamespace', 0)
# ('relisshared', 0)
# ('is_result', 0)
# ('typdelim', 0)
# ('typmodout', 0)
# ('Partner', 0)
# ('most_common_elems', 0)
# ('stxowner', 0)
# ('aggfinalfn', 0)
# ('evtenabled', 0)
# ('current_locker_pid', 0)
# ('is_trigger_insertable_into', 0)
# ('sql_data_access', 0)
# ('is_scrollable', 0)
# ('tuple', 0)
# ('cache_size', 0)
# ('stavalues4', 0)
# ('amopopr', 0)
# ('objname', 0)
# ('collicurules', 0)
# ('refclassid', 0)
# ('PaperlessBilling', 0)
# ('puballtables', 0)
# ('replay_lsn', 0)
# ('default_version', 0)
# ('rolreplication', 0)
# ('sequence_name', 0)
# ('indexname', 0)
# ('name', 0)
# ('interval_precision', 0)
# ('aggsortop', 0)
# ('opfowner', 0)
# ('condeferrable', 0)
# ('client_hostname', 0)
# ('object', 0)
# ('principal', 0)
# ('opcintype', 0)
# ('amprocfamily', 0)
# ('comment', 0)
# ('inherited', 0)
# ('cycle', 0)
# ('foreign_table_name', 0)
# ('daticurules', 0)
# ('query_id', 0)
# ('inhseqno', 0)
# ('checksum_failures', 0)
# ('extra_desc', 0)
# ('procost', 0)
# ('atthasmissing', 0)
# ('hasindexes', 0)
# ('checksum_last_failure', 0)
# ('conindid', 0)
# ('sub_feature_name', 0)
# ('n_mod_since_analyze', 0)
# ('stakind2', 0)
# ('nulls_distinct', 0)
# ('proargtypes', 0)
# ('OnlineBackup', 0)
# ('active_pid', 0)
# ('typcollation', 0)
# ('rulename', 0)
# ('cipher', 0)
# ('blk_read_time', 0)
# ('read_time', 0)
# ('default_collate_name', 0)
# ('stavalues3', 0)
# ('trftosql', 0)
# ('attribute_default', 0)
# ('rule_number', 0)
# ('short_desc', 0)
# ('parameter_mode', 0)
# ('event_object_table', 0)
# ('collation_catalog', 0)
# ('action_order', 0)
# ('condefault', 0)
# ('trftype', 0)
# ('cycle_option', 0)
# ('subrunasowner', 0)
# ('enumlabel', 0)
# ('client_addr', 0)
# ('self_time', 0)
# ('aggdeserialfn', 0)
# ('character_repertoire', 0)
# ('tmpllexize', 0)
# ('cmd', 0)
# ('version', 0)
# ('staop5', 0)
# ('proisstrict', 0)
# ('attribute_name', 0)
# ('typinput', 0)
# ('lomowner', 0)
# ('typndims', 0)
# ('relispopulated', 0)
# ('object_type', 0)
# ('indexrelname', 0)
# ('indoption', 0)
# ('is_trigger_deletable', 0)
# ('definition', 0)
# ('attalign', 0)
# ('autoanalyze_count', 0)
# ('spill_count', 0)
# ('reloptions', 0)
# ('relpersistence', 0)
# ('srvname', 0)
# ('error', 0)
# ('substream', 0)
# ('idx_scan', 0)
# ('op_bytes', 0)
# ('prsnamespace', 0)
# ('catalog_xmin', 0)
# ('writeback_time', 0)
# ('checkpoints_timed', 0)
# ('action_condition', 0)
# ('stanullfrac', 0)
# ('aggmfinalmodify', 0)
# ('role_name', 0)
# ('n_tup_upd', 0)
# ('temp_bytes', 0)
# ('library_name', 0)
# ('tablespaces_streamed', 0)
# ('is_trigger_updatable', 0)
# ('backend_xmin', 0)
# ('lockers_total', 0)
# ('elem_count_histogram', 0)
# ('atttypmod', 0)
# ('reset_val', 0)
# ('flush_lag', 0)
# ('confl_tablespace', 0)
# ('collection_type_identifier', 0)
# ('backend_type', 0)
# ('relminmxid', 0)
# ('confdeltype', 0)
# ('aggcombinefn', 0)
# ('description', 0)
# ('polrelid', 0)
# ('latest_end_lsn', 0)
# ('dependent_column', 0)
# ('module_catalog', 0)
# ('specific_name', 0)
# ('proleakproof', 0)
# ('tgconstrrelid', 0)
# ('constraint_name', 0)
# ('rolvaliduntil', 0)
# ('prattrs', 0)
# ('datacl', 0)
# ('tgrelid', 0)
# ('attcompression', 0)
# ('ordering_routine_catalog', 0)
# ('owner', 0)
# ('wait_event_type', 0)
# ('reuses', 0)
# ('most_common_elem_freqs', 0)
# ('stavalues5', 0)
# ('tgconstrindid', 0)
# ('pubname', 0)
# ('transaction', 0)
# ('is_null_call', 0)
# ('flushed_lsn', 0)
# ('sequenceowner', 0)
# ('datconnlimit', 0)
# ('ordering_routine_schema', 0)
# ('tgnewtable', 0)
# ('stawidth', 0)
# ('oprright', 0)
# ('character_set_name', 0)
# ('indisreplident', 0)
# ('event_object_column', 0)
# ('result_cast_numeric_precision', 0)
# ('oprnamespace', 0)
# ('typreceive', 0)
# ('conowner', 0)
# ('stxdndistinct', 0)
# ('aggminitval', 0)
# ('indnatts', 0)
# ('partattrs', 0)
# ('conparentid', 0)
# ('relowner', 0)
# ('plugin', 0)
# ('receive_start_tli', 0)
# ('subtwophasestate', 0)
# ('bytes_processed', 0)
# ('conexclop', 0)
# ('fdwhandler', 0)
# ('aggtransfn', 0)
# ('confrelid', 0)
# ('srvowner', 0)
# ('amhandler', 0)
# ('routine_definition', 0)
# ('extname', 0)
# ('stxrelid', 0)
# ('enumsortorder', 0)
# ('xmin', 0)
# ('blks_hit', 0)
# ('oprkind', 0)
# ('n_ins_since_vacuum', 0)
# ('confl_deadlock', 0)
# ('identity_generation', 0)
# ('castcontext', 0)
# ('tgparentid', 0)
# ('conkey', 0)
# ('partstrat', 0)
# ('self_referencing_column_name', 0)
# ('setting', 0)
# ('index_relid', 0)
# ('specific_catalog', 0)
# ('prosrc', 0)
# ('pubupdate', 0)
# ('stanumbers3', 0)
# ('rngsubtype', 0)
# ('result_types', 0)
# ('writebacks', 0)
# ('flush_lsn', 0)
# ('table_type', 0)
# ('restart_lsn', 0)
# ('matviewowner', 0)
# ('spill_txns', 0)
# ('gender', 0)
# ('exprs', 0)
# ('passwd', 0)
# ('prolang', 0)
# ('flushes', 0)
# ('srsubid', 0)
# ('heap_tuples_written', 0)
# ('reads', 0)
# ('evtowner', 0)
# ('opcname', 0)
# ('OnlineSecurity', 0)
# ('stream_bytes', 0)
# ('roname', 0)
# ('attbyval', 0)
# ('installed', 0)
# ('tgqual', 0)
# ('parameter_style', 0)
# ('typstorage', 0)
# ('result_cast_scope_catalog', 0)
# ('umserver', 0)
# ('view_name', 0)
# ('dictname', 0)
# ('usebypassrls', 0)
# ('opcmethod', 0)
# ('dictnamespace', 0)
# ('opfnamespace', 0)
# ('typdefaultbin', 0)
# ('pad_attribute', 0)
# ('unique_constraint_catalog', 0)
# ('source', 0)
# ('typarray', 0)
# ('creation_time', 0)
# ('amprocrighttype', 0)
# ('statement', 0)
# ('skip_new', 0)
# ('routine_schema', 0)
# ('result_cast_char_set_catalog', 0)
# ('seqcache', 0)
# ('last_seq_scan', 0)
# ('datetime_precision', 0)
# ('to_sql_specific_catalog', 0)
# ('issuer_dn', 0)
# ('stakind4', 0)
# ('indexprs', 0)
# ('aggserialfn', 0)
# ('oprcanhash', 0)
# ('sync_state', 0)
# ('aggtranstype', 0)
# ('indisexclusion', 0)
# ('integer_value', 0)
# ('default_collate_schema', 0)
# ('default_collate_catalog', 0)
# ('tenure', 0)
# ('prrelid', 0)
# ('attribute_udt_name', 0)
# ('vartype', 0)
# ('pronargs', 0)
# ('subdbid', 0)
# ('partdefid', 0)
# ('commit_action', 0)
# ('collctype', 0)
# ('extend_time', 0)
# ('trffromsql', 0)
# ('srvacl', 0)
# ('extversion', 0)
# ('expr', 0)
# ('options', 0)
# ('parameter_name', 0)
# ('rngsubdiff', 0)
# ('relreplident', 0)
# ('attnames', 0)
# ('off', 0)
# ('foreign_data_wrapper_catalog', 0)
# ('total_time', 0)
# ('is_typed', 0)
# ('confl_bufferpin', 0)
# ('minimum_value', 0)
# ('heap_blks_scanned', 0)
# ('heap_blks_total', 0)
# ('stainherit', 0)
# ('ev_class', 0)
# ('character_value', 0)
# ('attribute_udt_catalog', 0)
# ('opcowner', 0)
# ('viewowner', 0)
# ('slot_type', 0)
# ('unit', 0)
# ('opfname', 0)
# ('grosysid', 0)
# ('granted', 0)
# ('result_cast_dtd_identifier', 0)
# ('typrelid', 0)
# ('amname', 0)
# ('tup_returned', 0)
# ('amoppurpose', 0)
# ('hits', 0)
# ('last_archived_time', 0)
# ('xact_rollback', 0)
# ('oprcanmerge', 0)
# ('prepared', 0)
# ('stakind1', 0)
# ('lanispl', 0)
# ('opcdefault', 0)
# ('foreign_table_catalog', 0)
# ('member', 0)
# ('index_vacuum_count', 0)
# ('partrelid', 0)
# ('module_schema', 0)
# ('rngmultitypid', 0)
# ('reference_type', 0)
# ('confdelsetcols', 0)
# ('command', 0)
# ('default_character_set_name', 0)
# ('defaclobjtype', 0)
# ('buffers_checkpoint', 0)
# ('rngcollation', 0)
# ('extconfig', 0)
# ('collname', 0)
# ('Contract', 0)
# ('refobjid', 0)
# ('amopfamily', 0)
# ('source_dtd_identifier', 0)
# ('stream_count', 0)
# ('is_deterministic', 0)
# ('correlation', 0)
# ('result_cast_numeric_scale', 0)
# ('relhastriggers', 0)
# ('castsource', 0)
# ('truncates', 0)
# ('temp_files', 0)
# ('relkind', 0)
# ('received_lsn', 0)
# ('reltype', 0)
# ('leader_pid', 0)
# ('paracl', 0)
# ('dicttemplate', 0)
# ('datcollversion', 0)
# ('typtypmod', 0)
# ('lanplcallfoid', 0)
# ('typsend', 0)
# ('indnkeyatts', 0)
# ('stxstattarget', 0)
# ('oprowner', 0)
# ('proacl', 0)
# ('parameter_default', 0)
# ('policyname', 0)
# ('event_object_schema', 0)
# ('routine_name', 0)
# ('mapseqno', 0)
# ('srvtype', 0)
# ('backend_start', 0)
# ('setconfig', 0)
# ('netmask', 0)
# ('result_cast_collation_catalog', 0)
# ('relname', 0)
# ('ftrelid', 0)
# ('collisdeterministic', 0)
# ('stxoid', 0)
# ('remote_lsn', 0)
# ('stanumbers5', 0)
# ('polname', 0)
# ('table_schema', 0)
# ('statistics_name', 0)
# ('amprocnum', 0)
# ('indcheckxmin', 0)
# ('is_holdable', 0)
# ('created', 0)
# ('contype', 0)
# ('reltoastrelid', 0)
# ('active_time', 0)
# ('stats_reset', 0)
# ('pronamespace', 0)
# ('ev_type', 0)
# ('with_check', 0)
# ('attstorage', 0)
# ('datid', 0)
# ('tmplname', 0)
# ('evtfoid', 0)
# ('delete_rule', 0)
# ('reply_time', 0)
# ('datctype', 0)
# ('prosupport', 0)
# ('statistics_schemaname', 0)
# ('most_common_val_nulls', 0)
# ('is_verified_by', 0)
# ('last_msg_receipt_time', 0)
# ('size', 0)
# ('stxdmcv', 0)
# ('stxexprs', 0)
# ('most_common_freqs', 0)
# ('action_reference_new_table', 0)
# ('collencoding', 0)
# ('tmplinit', 0)
# ('external_name', 0)
# ('tidx_blks_read', 0)
# ('user_defined_type_catalog', 0)
# ('virtualtransaction', 0)
# ('subskiplsn', 0)
# ('objoid', 0)
# ('attrelid', 0)
# ('is_derived_reference_attribute', 0)
# ('sessions_abandoned', 0)
# ('confl_active_logicalslot', 0)
# ('query', 0)
# ('subenabled', 0)
# ('pnpubid', 0)
# ('buffers_alloc', 0)
# ('aggnumdirectargs', 0)
# ('domain_default', 0)
# ('prepare_time', 0)
# ('index_rebuild_count', 0)
# ('typoutput', 0)
# ('enumtypid', 0)
# ('blks_read', 0)
# ('confirmed_flush_lsn', 0)
# ('last_failed_time', 0)
# ('prokind', 0)
# ('indisunique', 0)
# ('pubviaroot', 0)
# ('deadlocks', 0)
# ('map_number', 0)
# ('collnamespace', 0)
# ('write_time', 0)
# ('type_udt_catalog', 0)
# ('polqual', 0)
# ('evictions', 0)
# ('total_nblocks', 0)
# ('typelem', 0)
# ('oprleft', 0)
# ('typbyval', 0)
# ('rolbypassrls', 0)
# ('trigger_name', 0)
# ('foreign_data_wrapper_name', 0)
# ('last_analyze', 0)
# ('supported_value', 0)
# ('is_generated', 0)
# ('proparallel', 0)
# ('interval_type', 0)
# ('object_schema', 0)
# ('seqno', 0)
# ('stadistinct', 0)
# ('stanumbers1', 0)
# ('tuples_processed', 0)
# ('last_value', 0)
# ('routine_catalog', 0)
# ('reltablespace', 0)
# ('proargdefaults', 0)
# ('local_id', 0)
# ('sample_blks_scanned', 0)
# ('nspname', 0)
# ('domain_schema', 0)
# ('prorows', 0)
# ('security_type', 0)
# ('attinhcount', 0)
# ('collation_name', 0)
# ('TotalCharges', 0)
# ('conpfeqop', 0)
# ('amproc', 0)
# ('defaclrole', 0)
# ('most_common_vals', 0)
# ('indnullsnotdistinct', 0)
# ('evtname', 0)
# ('stavalues1', 0)
# ('tup_fetched', 0)
# ('sizing_name', 0)
# ('scope_schema', 0)
# ('aggmtransfn', 0)
# ('identity_increment', 0)
# ('datdba', 0)
# ('objnamespace', 0)
# ('aggkind', 0)
# ('aggminvtransfn', 0)
# ('result_cast_collation_schema', 0)
# ('receive_start_lsn', 0)
# ('generation_expression', 0)
# ('identity_minimum', 0)
# ('sizing_id', 0)
# ('is_implicitly_invocable', 0)
# ('constraint_schema', 0)
# ('result_cast_interval_precision', 0)
# ('result_cast_from_data_type', 0)
# ('external_id', 0)
# ('is_final', 0)
# ('datistemplate', 0)
# ('dictinitoption', 0)
# ('backup_total', 0)
# ('tup_deleted', 0)
# ('connamespace', 0)
# ('oprcode', 0)
# ('result_cast_char_octet_length', 0)
# ('rolconfig', 0)
# ('seqtypid', 0)
# ('proowner', 0)
# ('roident', 0)
# ('sync_error_count', 0)
# ('spcowner', 0)
# ('ident', 0)
# ('casttarget', 0)
# ('gss_authenticated', 0)
# ('failed_count', 0)
# ('written_lsn', 0)
# ('view_catalog', 0)
# ('heap_blks_vacuumed', 0)
# ('TechSupport', 0)
# ('foreign_server_version', 0)
# ('cfgname', 0)
# ('ftoptions', 0)
# ('ev_action', 0)
# ('reltuples', 0)
# ('address', 0)
# ('wal_sync', 0)
# ('n_tup_del', 0)
# ('attnotnull', 0)
# ('from_sql', 0)
# ('attfdwoptions', 0)
# ('feature_id', 0)
# ('sender_host', 0)
# ('checkpoint_write_time', 0)
# ('nspacl', 0)
# ('enforced', 0)
# ('indisvalid', 0)
# ('dictowner', 0)
# ('is_insertable_into', 0)
# ('typname', 0)
# ('sourceline', 0)
# ('generic_plans', 0)
# ('castmethod', 0)
# ('foreign_table_schema', 0)
# ('result_cast_as_locator', 0)
# ('routine_type', 0)
# ('histogram_bounds', 0)
# ('aggmtranstype', 0)
# ('n_live_tup', 0)
# ('numeric_precision_radix', 0)
# ('user_defined_type_category', 0)
# ('ordering_routine_name', 0)
# ('is_instantiable', 0)
# ('datcollate', 0)
# ('position_in_unique_constraint', 0)
# ('proargmodes', 0)
# ('matviewname', 0)
# ('last_autoanalyze', 0)
# ('ssl', 0)
# ('dependencies', 0)
# ('funcid', 0)
# ('tgtype', 0)
# ('relpages', 0)
# ('database', 0)
# ('option_name', 0)
# ('scope_catalog', 0)
# ('umid', 0)
# ('auth_method', 0)
# ('parname', 0)
# ('blks_written', 0)
# ('collcollate', 0)
# ('Churn', 0)
# ('typowner', 0)
# ('null_frac', 0)
# ('attislocal', 0)
# ('subbinary', 0)
# ('sample_blks_total', 0)
# ('wal_bytes', 0)
# ('pending_restart', 0)
# ('initprivs', 0)
# ('classoid', 0)
# ('trigger_catalog', 0)
# ('pid', 0)
# ('action_reference_new_row', 0)
# ('category', 0)
# ('permissive', 0)
# ('fsyncs', 0)
# ('foreign_server_catalog', 0)
# ('lanacl', 0)
# ('stxkeys', 0)
# ('custom_plans', 0)
# ('temporary', 0)
# ('maximum_value', 0)
# ('relation', 0)
# ('srvfdw', 0)
# ('scope_name', 0)
# ('stanumbers4', 0)
# ('schema_level_routine', 0)
